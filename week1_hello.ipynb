# %% [markdown]
# # 第 1 周：环境验证
#
# 运行下面的代码单元格，确认 Python 环境与四个核心库都可用。

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

print("hello, intern")
print("numpy", np.__version__)
print("pandas", pd.__version__)
print("matplotlib", matplotlib.__version__)
